# %%
import requests 
import json

url = "https://dbc-b9e8bb32-1d55.cloud.databricks.com/serving-endpoints/bestmodel2/invocations"
token = ""

headers = {
    "Authorization": f"Bearer {token}",
    "Content-Type": "application/json"
}

data = {
    "dataframe_records": [
        {
            "age": 59.0,
            "sex": 2.0,
            "bmi": 32.1,
            "bp": 101.0,
            "s1": 157.0,
            "s2": 93.0,
            "s3": 38.0,
            "s4": 4.0,
            "s5": 4.8598,
            "s6": 87.0
        }
    ]
}

response = requests.post(url, headers=headers, json=data)
print("Status:", response.status_code)
print(response.json())
# Out:
# Status: 200
# {'predictions': [-28506.794149950056]}
